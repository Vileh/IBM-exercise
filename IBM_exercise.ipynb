# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio
# ---

# %% [markdown]
# **Viktor Penchev** <br>
# Student at UCL - Economics BSc <br>

# %% [markdown]
# *I'm interested in data science because of how creative the job is. I especially like the prosepct of solving real problems with which I can help people.*

# %% [markdown]
# ### This is a bad calculator that doesn't do your calculation

# %%
import random

w_1 = ['Sorry', 'Nope', ':|', 'Okay']
w_2 = [' not today.', " I won't.", ', maybe try again but probably not.', ' you should just use your phone']

print('Input calculation:')
input()
print(w_1[random.randint(0, len(w_1)-1)] + w_2[random.randint(0, len(w_2)-1)])
# Out:
# Input calculation:
#  1
# Okay not today.

# %% [markdown]
# ### Markdown features:
# 1. Horizontal rule
# ---
# 2. ~~strikethrough~~
# 3. The list itself
